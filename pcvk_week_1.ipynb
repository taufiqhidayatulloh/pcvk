# %% [markdown]
# <a href="https://colab.research.google.com/github/taufiqhidayatulloh/pcvk/blob/main/pcvk_week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Step 2

# %%
urls = ["https://asset.kompas.com/crops/PScDVjnwXVZ3QdXuaLh4tbKmToY=/0x0:612x408/750x500/data/photo/2023/08/07/64d09a80a12d4.jpeg",
        "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTaMrKpFCdbgQ3D1Nm9HMnJDdESq8GxBXIUmw&s","https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRbOBeafWIcnzuC1RsrGY4-EMW_03fB0Y5j7Q&s"]

for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=750x250>
# <PIL.Image.Image image mode=RGB size=224x112>
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# Step 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  84  x  150
# <PIL.Image.Image image mode=RGB size=150x84>

# %% [markdown]
# Step 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# **Pertanyaan**
#
#
#
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# - Karena Google Colab merupakan kode editor berbasis cloud sehingga user tidak perlu menyiapakan/mengisnstall phyton dan library sendiri.
# 2.   Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - Numpy merupakan library untuk memanipulasi dan mengolah data dalam bentuk array. Pandas merupakan library yang digunakan untuk memanipulasi dan menganalisis data. CV2 merupakan library untuk computer vision dan pemrosesan gambar. Skimage merupakan library yang membantu aplikasi pemrosesan gambar pada phyton. Matplotlib merupakan library untuk menghasilkan gambar dan menyediakan GUI toolkit
# - Library yang dipanggil, belum dipakai semua hingga pada 'Step 4'
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut <br>
# ```image = cv.resize(image, (0,0), fx=0.5, fy=0.5)```<br>
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# - Kode program tersebut berfungsi untuk mengubah ukuran gambar dengan skala 0.5 dari ukuran gambar asli.
# 4. Perhatikan potongan kode progam berikut : <br>
# ```for y in range (lebar):
#   image_3[int((tinggi)/2), y] = [255, 255, 255]```
#   <br> Apakah kegunaan kode [255,255,255] ? Jelaskan!
# - Kode tersebut bertujuan untuk menjadikan sebuah pixel/array menjadi warna putih
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - Resolusi gambar yang tinggi berbanding lurus dengan banyaknya pixel pada suatu gambar. Sehingga semakin rendah resolusi, pixelnya juga akan semakin sedikit.

# %% [markdown]
# Tugas (Garis Vertikal dan diagonal)

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_d = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

#membuat garis diagonal silang ditengah image
for x in range(tinggi):
  # diagonal kiri
  image_d[x, int((lebar/tinggi)*x)] = [255, 255, 255]
  # diagonal kanan
  image_d[x, int((lebar/tinggi)*(tinggi-x-1))] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_d))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# Tugas (Garis tengah)

# %%
image_c = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
length = 30
for x in range(length):
  image_c[int((tinggi)/2), int(((lebar)/2)-(length/2)+x)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_c))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# Tugas (Kumpulan Pixel Putih)

# %%
image_sq = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat kotak di image disembarang tempat
position = [10, 10]
width = 40
for x in range(width):
  for y in range(width):
    image_sq[position[0]+x , position[1]+y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_sq))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
path = 'ktp.jpg'

image = io.imread(path)                           #read image
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
image_ktp = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB

nik = [60, 100, 25, 230]

name = [95, 120, 14, 180]

for x in range(nik[2]):
  for y in range(nik[3]):
    image_ktp[nik[0]+x , nik[1]+y] = [255, 0, 0]

for x in range(name[2]):
  for y in range(name[3]):
    image_ktp[name[0]+x , name[1]+y] = [0, 0, 0]


final_frame = cv.hconcat((image_2, image_ktp))
cv2_imshow(final_frame)                            #show image
print('\n')

plt.imshow(cv.cvtColor(image_ktp, cv.COLOR_RGB2BGR))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x330>
